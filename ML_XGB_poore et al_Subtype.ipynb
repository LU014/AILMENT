# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
#import graphviz

# %%
#abundance = pd.read_csv("TCGA_Poore/Kraken/Kraken-TCGA-Voom-SNM-Full-Data.csv", index_col=0)
abundance = pd.read_csv("TCGA_Poore/Kraken/Kraken-TCGA-Voom-SNM-All-Putative-Contaminants-Removed-Data.csv", index_col=0)
abundance = abundance[abundance.sum(axis = 1) > 0]
abundance = abundance.dropna()
print(abundance.shape)
# Out:
# (17625, 1411)

# %%
abundance
# Out:
#         k__Viruses.f__Phycodnaviridae.g__Prasinovirus  \
# s17489                                      -0.944325
# s17512                                       2.799427
# s17498                                      -0.350754
# s17528                                       2.163915
# s17535                                       0.053629
# ...                                               ...
# s23                                          0.284636
# s20                                          0.459102
# s27                                          2.354685
# s26                                          0.352523
# s41                                          0.145316
#
#         k__Viruses.o__Caudovirales.f__Siphoviridae.g__Sfi1unalikevirus  \
# s17489                                           1.378696
# s17512                                           2.095355
# s17498                                           1.969313
# s17528                                           1.915785
# s17535                                           2.127427
# ...                                                   ...
# s23                                              2.194480
# s20                                              2.421001
# s27                                              2.152569
# s26                                              2.472335
# s41                                              2.265128
#
#         k__Viruses.o__Herpesvirales.f__Herpesviridae.g__Simplexvirus  \
# s17489                                           4.257198
# s17512                                           5.282909
# s17498                                           4.789957
# s17528                                           4.830879
# s17535                                           3.664010
# ...                                                   ...
# s23                                              4.703390
# s20                                              4.873527
# s27                                              3.585112
# s26                                              4.215219
# s41                                              3.697671
#
#         k__Viruses.f__Poxviridae.g__Parapoxvirus  \
# s17489                                  2.263261
# s17512                                  0.625737
# s17498                                  0.645980
# s17528                                  0.699582
# s17535                                  0.911225
# ...                                          ...
# s23                                     0.814588
# s20                                     1.102422
# s27                                     0.904770
# s26                                     1.224536
# s41                                     1.017329
#
#         k__Viruses.f__Bicaudaviridae.g__Bicaudavirus  \
# s17489                                      0.478455
# s17512                                      1.262373
# s17498                                      1.072432
# s17528                                      1.110310
# s17535                                      1.321953
# ...                                              ...
# s23                                         1.239996
# s20                                         1.471217
# s27                                         1.340790
# s26                                         1.660556
# s41                                         1.453349
#
#         k__Viruses.o__Picornavirales.f__Picornaviridae.g__Aquamavirus  \
# s17489                                           3.283590
# s17512                                           2.598059
# s17498                                           2.454999
# s17528                                           0.812846
# s17535                                           3.560542
# ...                                                   ...
# s23                                              1.451831
# s20                                              1.771189
# s27                                              1.417062
# s26                                              1.736829
# s41                                              1.529622
#
#         k__Viruses.o__Herpesvirales.f__Herpesviridae.g__Mardivirus  \
# s17489                                           6.175448
# s17512                                           5.032088
# s17498                                           6.929492
# s17528                                           5.856873
# s17535                                           6.068515
# ...                                                   ...
# s23                                              7.643768
# s20                                              3.612937
# s27                                              7.595169
# s26                                              7.021851
# s41                                              7.177214
#
#         k__Viruses.f__Baculoviridae.g__Deltabaculovirus  \
# s17489                                         0.554111
# s17512                                        -0.978710
# s17498                                        -1.045204
# s17528                                         1.314613
# s17535                                        -0.795673
# ...                                                 ...
# s23                                           -0.498119
# s20                                           -0.324706
# s27                                           -0.405086
# s26                                           -0.085319
# s41                                           -0.292526
#
#         k__Viruses.f__Papillomaviridae.g__Taupapillomavirus  \
# s17489                                           1.707182
# s17512                                          -0.066234
# s17498                                           4.299620
# s17528                                           2.308325
# s17535                                           0.198039
# ...                                                   ...
# s23                                              3.479699
# s20                                              1.182912
# s27                                              0.796029
# s26                                              1.115795
# s41                                              2.493551
#
#         k__Viruses.o__Caudovirales.f__Myoviridae.g__I3likevirus  ...  \
# s17489                                          -2.701144        ...
# s17512                                           0.042982        ...
# s17498                                           0.037454        ...
# s17528                                           1.252654        ...
# s17535                                          -1.705629        ...
# ...                                                   ...        ...
# s23                                             -1.214270        ...
# s20                                             -1.272753        ...
# s27                                             -1.078900        ...
# s26                                             -0.759133        ...
# s41                                             -0.966340        ...
#
#         k__Bacteria.p__Firmicutes.c__Clostridia.o__Clostridiales.f__Clostridiales_Family_XIII._Incertae_Sedis.g__Casaltella  \
# s17489                                           2.952431
# s17512                                           3.623247
# s17498                                           3.531484
# s17528                                           3.649382
# s17535                                           3.861024
# ...                                                   ...
# s23                                              3.606118
# s20                                              3.855399
# s27                                              3.627826
# s26                                              3.947592
# s41                                              3.740385
#
#         k__Bacteria.p__Proteobacteria.c__Betaproteobacteria.o__Neisseriales.f__Chromobacteriaceae.g__Deefgea  \
# s17489                                           1.053012
# s17512                                           2.048703
# s17498                                           1.879986
# s17528                                           1.827052
# s17535                                           2.038694
# ...                                                   ...
# s23                                              2.043599
# s20                                              2.293863
# s27                                              2.068357
# s26                                              2.388124
# s41                                              2.180917
#
#         k__Bacteria.p__Proteobacteria.c__Alphaproteobacteria.o__Rhizobiales.f__Phyllobacteriaceae.g__Aquamicrobium  \
# s17489                                           1.641701
# s17512                                           2.357091
# s17498                                           2.273343
# s17528                                           2.385817
# s17535                                           2.597460
# ...                                                   ...
# s23                                              2.325969
# s20                                              2.546157
# s27                                              2.344308
# s26                                              2.664075
# s41                                              2.456867
#
#         k__Bacteria.p__Deferribacteres.c__Deferribacteres.o__Deferribacterales.f__Deferribacteraceae.g__Geovibrio  \
# s17489                                           1.597915
# s17512                                           2.339657
# s17498                                           2.176359
# s17528                                           2.223181
# s17535                                           2.434824
# ...                                                   ...
# s23                                              2.347134
# s20                                              2.490664
# s27                                              2.365683
# s26                                              2.685449
# s41                                              2.478242
#
#         k__Bacteria.p__Firmicutes.c__Clostridia.o__Clostridiales.f__Ruminococcaceae.g__Subdoligranulum  \
# s17489                                           1.615110
# s17512                                           2.378702
# s17498                                           2.268394
# s17528                                           2.313300
# s17535                                           2.524942
# ...                                                   ...
# s23                                              2.320139
# s20                                              2.572189
# s27                                              2.353494
# s26                                              2.673261
# s41                                              2.466053
#
#         contaminant1Harvard  contaminant2HarvardCanadaBaylorWashU  \
# s17489             1.613142                             12.579647
# s17512             2.338944                             13.305450
# s17498             2.254124                             13.220630
# s17528             2.361125                             13.327630
# s17535             2.572767                             13.539273
# ...                     ...                                   ...
# s23                2.292332                             13.258838
# s20                2.545829                             13.512334
# s27                2.348888                             13.315394
# s26                2.668655                             13.635160
# s41                2.461448                             13.427953
#
#         contaminant3AllSeqCenters  contaminant4RandomSpikesHarvard  \
# s17489                  12.579647                         1.579534
# s17512                  13.305450                         2.332050
# s17498                  13.220630                         2.211553
# s17528                  13.327630                         2.164692
# s17535                  13.539273                         2.376335
# ...                           ...                              ...
# s23                     13.258838                         2.259281
# s20                     13.512334                         2.537966
# s27                     13.315394                         2.232305
# s26                     13.635160                         2.552071
# s41                     13.427953                         2.344864
#
#         contaminant5RandomSpikes1000
# s17489                      2.482244
# s17512                      2.855626
# s17498                      3.193130
# s17528                      3.090736
# s17535                      3.302378
# ...                              ...
# s23                         3.443482
# s20                         3.876017
# s27                         3.625496
# s26                         3.945263
# s41                        24.669625
#
# [17625 rows x 1411 columns]

# %%
abundance_df = pd.DataFrame(abundance)

# Define a list of invalid names: no information or virus are invalid
invalid_names = ['f__.g__.s__','g__.s__','virus']

# Iterate over columns and drop those containing invalid names
for col in abundance_df.columns:
    if any(invalid_name in col for invalid_name in invalid_names):
        abundance_df.drop(col, axis=1, inplace=True)

# Extract family, genera, and species from existing column names
def extract_taxonomy(column):
    return '; '.join([t for t in column.split('.') if t.startswith('f__') or t.startswith('g__') or t.startswith('s__')])

# Create new column names
new_columns = [extract_taxonomy(column) for column in abundance_df.columns]

# Rename columns
abundance_df.columns = new_columns

abundance_df
# Out:
#         f__Halomonadaceae; g__Cobetia  \
# s17489                       0.750758
# s17512                       2.957832
# s17498                       2.865233
# s17528                       1.331853
# s17535                      -0.041467
# ...                               ...
# s23                          1.492351
# s20                          1.642807
# s27                          1.422109
# s26                          1.741875
# s41                          1.534668
#
#         f__Thermoanaerobacteraceae; g__Ammonifex  \
# s17489                                  1.698080
# s17512                                  2.437834
# s17498                                  2.223742
# s17528                                  2.394651
# s17535                                  2.606293
# ...                                          ...
# s23                                     2.495612
# s20                                     2.709255
# s27                                     2.568446
# s26                                     2.888213
# s41                                     2.681005
#
#         f__Cryomorphaceae; g__Owenweeksia  f__Haloplasmataceae; g__Haloplasma  \
# s17489                           1.211822                            2.098064
# s17512                           1.979203                            0.569559
# s17498                           1.849716                            0.408622
# s17528                           1.813642                            0.501072
# s17535                           2.025285                            2.297677
# ...                                   ...                                 ...
# s23                              2.118032                            0.773989
# s20                              2.253808                            1.035752
# s27                              2.202434                            0.955879
# s26                              2.522201                            1.275646
# s41                              2.314993                            2.653401
#
#         f__Desulfobacteraceae; g__Desulfosarcina  \
# s17489                                  1.901532
# s17512                                  1.184304
# s17498                                  2.003357
# s17528                                  0.985425
# s17535                                 -0.041719
# ...                                          ...
# s23                                     0.951887
# s20                                     2.675408
# s27                                     1.782572
# s26                                     1.571824
# s41                                     1.364617
#
#         f__Enterobacteriaceae; g__Siccibacter  f__Acetobacteraceae; g__Asaia  \
# s17489                               0.746481                      -0.731171
# s17512                               1.657705                       0.251591
# s17498                               1.461779                       1.840733
# s17528                               3.488439                       4.899925
# s17535                               1.378154                       2.874528
# ...                                       ...                            ...
# s23                                  2.135941                       3.213407
# s20                                  2.310780                       1.919476
# s27                                  2.043960                       1.740752
# s26                                  2.363727                       2.060519
# s41                                  2.156520                       1.853311
#
#         f__Rhodobiaceae; g__Parvibaculum  g__Neosynechococcus  \
# s17489                          0.069450             1.183112
# s17512                          2.690162             2.091016
# s17498                          0.527662             1.917301
# s17528                          2.730293             1.865934
# s17535                          0.620008             2.077577
# ...                                  ...                  ...
# s23                             1.754071             2.045186
# s20                             1.929309             2.437095
# s27                             1.762615             2.213836
# s26                             2.082382             2.533603
# s41                             1.875175             2.326396
#
#         f__Sphingomonadaceae; g__Zymomonas  ...  \
# s17489                            0.950821  ...
# s17512                           -0.634765  ...
# s17498                            1.279785  ...
# s17528                            1.824556  ...
# s17535                           -0.771157  ...
# ...                                    ...  ...
# s23                              -0.399423  ...
# s20                              -0.077439  ...
# s27                              -0.036487  ...
# s26                               0.283279  ...
# s41                               0.076072  ...
#
#         f__Clostridiales_Family_XIII; g__Casaltella  \
# s17489                                     2.952431
# s17512                                     3.623247
# s17498                                     3.531484
# s17528                                     3.649382
# s17535                                     3.861024
# ...                                             ...
# s23                                        3.606118
# s20                                        3.855399
# s27                                        3.627826
# s26                                        3.947592
# s41                                        3.740385
#
#         f__Chromobacteriaceae; g__Deefgea  \
# s17489                           1.053012
# s17512                           2.048703
# s17498                           1.879986
# s17528                           1.827052
# s17535                           2.038694
# ...                                   ...
# s23                              2.043599
# s20                              2.293863
# s27                              2.068357
# s26                              2.388124
# s41                              2.180917
#
#         f__Phyllobacteriaceae; g__Aquamicrobium  \
# s17489                                 1.641701
# s17512                                 2.357091
# s17498                                 2.273343
# s17528                                 2.385817
# s17535                                 2.597460
# ...                                         ...
# s23                                    2.325969
# s20                                    2.546157
# s27                                    2.344308
# s26                                    2.664075
# s41                                    2.456867
#
#         f__Deferribacteraceae; g__Geovibrio  \
# s17489                             1.597915
# s17512                             2.339657
# s17498                             2.176359
# s17528                             2.223181
# s17535                             2.434824
# ...                                     ...
# s23                                2.347134
# s20                                2.490664
# s27                                2.365683
# s26                                2.685449
# s41                                2.478242
#
#         f__Ruminococcaceae; g__Subdoligranulum                       \
# s17489                                1.615110  1.613142  12.579647
# s17512                                2.378702  2.338944  13.305450
# s17498                                2.268394  2.254124  13.220630
# s17528                                2.313300  2.361125  13.327630
# s17535                                2.524942  2.572767  13.539273
# ...                                        ...       ...        ...
# s23                                   2.320139  2.292332  13.258838
# s20                                   2.572189  2.545829  13.512334
# s27                                   2.353494  2.348888  13.315394
# s26                                   2.673261  2.668655  13.635160
# s41                                   2.466053  2.461448  13.427953
#
#
# s17489  12.579647  1.579534   2.482244
# s17512  13.305450  2.332050   2.855626
# s17498  13.220630  2.211553   3.193130
# s17528  13.327630  2.164692   3.090736
# s17535  13.539273  2.376335   3.302378
# ...           ...       ...        ...
# s23     13.258838  2.259281   3.443482
# s20     13.512334  2.537966   3.876017
# s27     13.315394  2.232305   3.625496
# s26     13.635160  2.552071   3.945263
# s41     13.427953  2.344864  24.669625
#
# [17625 rows x 1273 columns]

# %%
metadata = pd.read_csv('TCGA_Poore/Metadata-TCGA-All-18116-Samples.csv', index_col=0)
metadata = metadata[metadata['investigation'] == 'TCGA-COAD']
print(metadata)
# Out:
#                                gdc_file_uuid  \
# s13008  5DCDB663-BC72-4928-970A-2C50103CF337
# s12994  5220B7B2-6F81-4C7F-BFB4-B523C2C30DDF
# s13005  95F7BD48-5E28-4892-BC8D-A6DEC3B02D70
# s12987  78F6E4E8-1349-43CB-AAA7-C56FD833DEDD
# s12895  D04CC01A-3CCB-4FC1-BAD8-2EDE20790454
# ...                                      ...
# s13862  36293F9B-A284-467E-AB73-AE62FC5EAB6E
# s13849  86E4599E-AB45-4118-B105-32782288A0D3
# s13857  CCC44CA2-2E42-4083-9252-597D398BE401
# s13839  0DD44906-041D-4AF2-8F42-A1BED185E1C6
# s13842  7942EAB9-D80A-496E-B3CB-50B42BD23334
#
#                                                  filename  age_at_diagnosis  \
# s13008  UNCID_340264.TCGA-AZ-4615-01A-01R-1410-07.1103...              84.0
# s12994  UNCID_269004.TCGA-AA-A02R-01A-01R-A00A-07.1008...              84.0
# s13005  UNCID_339870.TCGA-AA-3488-01A-01R-1410-07.1103...              58.0
# s12987  UNCID_269354.TCGA-AA-3815-01A-01R-1022-07.1008...              65.0
# s12895  UNCID_1590129.79b022ed-6ef5-4140-9cd1-04c8af58...              66.0
# ...                                                   ...               ...
# s13862  UNCID_258932.TCGA-AA-A01G-01A-01R-A002-07.1006...              63.0
# s13849  UNCID_1618504.9c1d30c4-c8f0-4ca7-bec7-243f81b7...              72.0
# s13857  UNCID_1948345.0dc7cb6e-bb27-4da5-90ed-c062dc9f...              69.0
# s13839  TCGA-AA-A01T-01A-21D-A079-02_110402_SN208_0200...              63.0
# s13842  TCGA-AA-A02K-01A-21D-A079_110401_SN177_0152_A8...              50.0
#
#                                 aliquot_uuid  \
# s13008  6805B5DA-D028-436D-85A7-1D151DA16731
# s12994  3B40E36D-725C-4291-BEED-3FD394238B98
# s13005  98E3C8DD-71B9-4944-B7BB-AA216AAAC0AB
# s12987  EE944FBE-C1DE-4060-B05F-81CDE4EC0C27
# s12895  79B022ED-6EF5-4140-9CD1-04C8AF58A9DF
# ...                                      ...
# s13862  9D737CC8-0854-4559-AB65-B43485DDC035
# s13849  9C1D30C4-C8F0-4CA7-BEC7-243F81B7680A
# s13857  0DC7CB6E-BB27-4DA5-90ED-C062DC9FDA0B
# s13839  8F61B113-0E19-403E-9637-48E9D9733692
# s13842  7CC17F3D-27F5-484A-8E22-C9D0B5B27836
#
#                                    case_uuid  days_to_death  \
# s13008  bf69a4ce-ec7e-4752-a86d-dcc80e3c9a57            NaN
# s12994  764c97c9-01d3-45cb-86bd-f8a52b5468da          670.0
# s13005  6e9e0c2f-2ddb-40f1-8e8c-618119e62ec1          153.0
# s12987  b16bb717-d1cf-4237-a554-43f3995b82f2            NaN
# s12895  7dfbc0ed-e684-4966-8b59-fb6b9e80c129            NaN
# ...                                      ...            ...
# s13862  6f2b5a14-569c-4084-8c67-b1a44d787897            NaN
# s13849  ff1407c6-9174-4bae-a19b-d34ca71b898c            NaN
# s13857  14c13b05-abfe-472e-83a9-b28f60e58ad8            NaN
# s13839  f87c6dcc-1a9e-4df5-962c-1f946e2611f8            NaN
# s13842  10881458-55b2-41d1-8358-4ee6ccb8ec85          426.0
#
#                 disease_type               ethnicity experimental_strategy  \
# s13008  Colon Adenocarcinoma  NOT HISPANIC OR LATINO               RNA-Seq
# s12994  Colon Adenocarcinoma           Not available               RNA-Seq
# s13005  Colon Adenocarcinoma           Not available               RNA-Seq
# s12987  Colon Adenocarcinoma           Not available               RNA-Seq
# s12895  Colon Adenocarcinoma           Not available               RNA-Seq
# ...                      ...                     ...                   ...
# s13862  Colon Adenocarcinoma           Not available               RNA-Seq
# s13849  Colon Adenocarcinoma  NOT HISPANIC OR LATINO               RNA-Seq
# s13857  Colon Adenocarcinoma  NOT HISPANIC OR LATINO               RNA-Seq
# s13839  Colon Adenocarcinoma           Not available                   WGS
# s13842  Colon Adenocarcinoma           Not available                   WGS
#
#         gender  ... portion_weight aliquot_concentration  \
# s13008    MALE  ...           36.0                  0.14
# s12994  FEMALE  ...          110.0                  0.15
# s13005    MALE  ...          137.0                  0.17
# s12987  FEMALE  ...          158.0                  0.14
# s12895    MALE  ...          114.0                  0.13
# ...        ...  ...            ...                   ...
# s13862    MALE  ...          110.0                  0.15
# s13849  FEMALE  ...          129.0                  0.15
# s13857    MALE  ...           36.0                  0.14
# s13839  FEMALE  ...           30.0                  0.14
# s13842    MALE  ...           30.0                  0.15
#
#        analyte_A260A280Ratio analyte_amount analyte_type_label  \
# s13008                  1.80         147.30                RNA
# s12994                  1.72         132.38                RNA
# s13005                  1.80         583.30                RNA
# s12987                  1.80         438.30                RNA
# s12895                  1.80         533.30                RNA
# ...                      ...            ...                ...
# s13862                  1.73         239.76                RNA
# s13849                  1.80         877.30                RNA
# s13857                  1.70          19.80                RNA
# s13839                  2.03          80.04                DNA
# s13842                  1.90          28.83                DNA
#
#                 radiation_therapy_code_label radiation_therapy_site_label  \
# s13008                                   NaN                          NaN
# s12994                                   NaN                          NaN
# s13005                                   NaN                          NaN
# s12987                                   NaN                          NaN
# s12895                                   NaN                          NaN
# ...                                      ...                          ...
# s13862                                   NaN                          NaN
# s13849                                   NaN                          NaN
# s13857  951909FD-4B2B-4D3F-918A-34269D0A70FC          Primary Tumor Field
# s13839                                   NaN                          NaN
# s13842                                   NaN                          NaN
#
#        radiation_therapy_type_label year_of_diagnosis vital_status_label
# s13008                          NaN            2009.0              Alive
# s12994                          NaN            2006.0               Dead
# s13005                          NaN            2002.0               Dead
# s12987                          NaN            2007.0              Alive
# s12895                          NaN            2009.0              Alive
# ...                             ...               ...                ...
# s13862                          NaN            2009.0              Alive
# s13849                          NaN            2009.0              Alive
# s13857                EXTERNAL BEAM            2008.0              Alive
# s13839                          NaN            2004.0              Alive
# s13842                          NaN            2009.0               Dead
#
# [1017 rows x 41 columns]

# %%
print(metadata.columns)
# Out:
# Index(['gdc_file_uuid', 'filename', 'age_at_diagnosis', 'aliquot_uuid',
#        'case_uuid', 'days_to_death', 'disease_type', 'ethnicity',
#        'experimental_strategy', 'gender', 'investigation', 'platform',
#        'primary_site', 'race', 'reference_genome', 'sample_type',
#        'sample_uuid', 'vital_status', 'tissue_source_site_label',
#        'data_submitting_center_label', 'country_of_sample_procurement',
#        'histological_diagnosis_label', 'pathologic_t_label',
#        'pathologic_n_label', 'pathologic_stage_label', 'icd03_histology_label',
#        'icd03_histology_site', 'icd10', 'portion_is_ffpe',
#        'new_tumor_event_after_initial_trtmt',
#        'primary_therapy_outcome_success_label', 'portion_weight',
#        'aliquot_concentration', 'analyte_A260A280Ratio', 'analyte_amount',
#        'analyte_type_label', 'radiation_therapy_code_label',
#        'radiation_therapy_site_label', 'radiation_therapy_type_label',
#        'year_of_diagnosis', 'vital_status_label'],
#       dtype='object')

# %%
scaler = StandardScaler()

# %%
COAD = pd.merge(abundance_df, metadata, left_index=True, right_index=True)
COAD = COAD
#merged_df.head
COAD.shape
COAD
# Out:
#         f__Halomonadaceae; g__Cobetia  \
# s13008                       0.549996
# s12994                       1.036992
# s13005                       0.391081
# s12987                       0.307795
# s12895                       1.091898
# ...                               ...
# s13862                       0.955064
# s13849                       2.017887
# s13857                       3.343320
# s13839                       1.289116
# s13842                       1.310620
#
#         f__Thermoanaerobacteraceae; g__Ammonifex  \
# s13008                                  3.627426
# s12994                                  2.472233
# s13005                                  4.148250
# s12987                                  1.743036
# s12895                                  2.527139
# ...                                          ...
# s13862                                  2.390305
# s13849                                  1.819532
# s13857                                  2.743249
# s13839                                  2.429583
# s13842                                  2.451087
#
#         f__Cryomorphaceae; g__Owenweeksia  f__Haloplasmataceae; g__Haloplasma  \
# s13008                           1.243335                            0.200708
# s12994                           1.813183                            0.705863
# s13005                           3.489199                            0.059951
# s12987                           2.668948                           -0.023334
# s12895                           1.868089                            2.345731
# ...                                   ...                                 ...
# s13862                           1.731255                            0.623935
# s13849                           0.994857                            4.463031
# s13857                           2.314112                            1.020499
# s13839                           3.706441                            2.381846
# s13842                           3.727945                            0.081422
#
#         f__Desulfobacteraceae; g__Desulfosarcina  \
# s13008                                 -0.019726
# s12994                                 -0.388531
# s13005                                 -1.034442
# s12987                                 -1.117728
# s12895                                  1.251338
# ...                                          ...
# s13862                                  1.114504
# s13849                                 -1.705226
# s13857                                  3.378589
# s13839                                  1.259359
# s13842                                  1.049538
#
#         f__Enterobacteriaceae; g__Siccibacter  f__Acetobacteraceae; g__Asaia  \
# s13008                               3.566605                       1.143794
# s12994                               1.471217                       1.448203
# s13005                               0.825306                       2.387254
# s12987                               0.742020                       2.303968
# s12895                               1.526123                       1.503109
# ...                                       ...                            ...
# s13862                               1.389289                       3.688203
# s13849                               0.701323                       0.955917
# s13857                               3.974225                       1.981555
# s13839                               2.226014                       1.631685
# s13842                               2.247518                       1.653189
#
#         f__Rhodobiaceae; g__Parvibaculum  g__Neosynechococcus  \
# s13008                          3.529965             1.626574
# s12994                          1.290475             2.069139
# s13005                          3.451919             3.745155
# s12987                          0.561278             1.339942
# s12895                          1.345381             2.124045
# ...                                  ...                  ...
# s13862                          1.208548             1.987211
# s13849                          0.587535             1.494217
# s13857                          1.969840             2.411123
# s13839                          1.822473             2.084668
# s13842                          1.843978             3.691135
#
#         f__Sphingomonadaceae; g__Zymomonas  ...  portion_weight  \
# s13008                           -0.920077  ...            36.0
# s12994                           -0.342958  ...           110.0
# s13005                            0.596093  ...           137.0
# s12987                           -1.072154  ...           158.0
# s12895                           -0.288051  ...           114.0
# ...                                    ...  ...             ...
# s13862                           -0.424885  ...           110.0
# s13849                           -1.100823  ...           129.0
# s13857                            0.229642  ...            36.0
# s13839                            2.162532  ...            30.0
# s13842                           -0.137892  ...            30.0
#
#         aliquot_concentration  analyte_A260A280Ratio  analyte_amount  \
# s13008                   0.14                   1.80          147.30
# s12994                   0.15                   1.72          132.38
# s13005                   0.17                   1.80          583.30
# s12987                   0.14                   1.80          438.30
# s12895                   0.13                   1.80          533.30
# ...                       ...                    ...             ...
# s13862                   0.15                   1.73          239.76
# s13849                   0.15                   1.80          877.30
# s13857                   0.14                   1.70           19.80
# s13839                   0.14                   2.03           80.04
# s13842                   0.15                   1.90           28.83
#
#         analyte_type_label          radiation_therapy_code_label  \
# s13008                 RNA                                   NaN
# s12994                 RNA                                   NaN
# s13005                 RNA                                   NaN
# s12987                 RNA                                   NaN
# s12895                 RNA                                   NaN
# ...                    ...                                   ...
# s13862                 RNA                                   NaN
# s13849                 RNA                                   NaN
# s13857                 RNA  951909FD-4B2B-4D3F-918A-34269D0A70FC
# s13839                 DNA                                   NaN
# s13842                 DNA                                   NaN
#
#         radiation_therapy_site_label  radiation_therapy_type_label  \
# s13008                           NaN                           NaN
# s12994                           NaN                           NaN
# s13005                           NaN                           NaN
# s12987                           NaN                           NaN
# s12895                           NaN                           NaN
# ...                              ...                           ...
# s13862                           NaN                           NaN
# s13849                           NaN                           NaN
# s13857           Primary Tumor Field                 EXTERNAL BEAM
# s13839                           NaN                           NaN
# s13842                           NaN                           NaN
#
#         year_of_diagnosis  vital_status_label
# s13008             2009.0               Alive
# s12994             2006.0                Dead
# s13005             2002.0                Dead
# s12987             2007.0               Alive
# s12895             2009.0               Alive
# ...                   ...                 ...
# s13862             2009.0               Alive
# s13849             2009.0               Alive
# s13857             2008.0               Alive
# s13839             2004.0               Alive
# s13842             2009.0                Dead
#
# [1006 rows x 1314 columns]

# %%
class_counts = COAD['sample_type'].value_counts()
print(class_counts)
# Out:
# sample_type
# Primary Tumor           825
# Blood Derived Normal    109
# Solid Tissue Normal      70
# Metastatic                1
# Recurrent Tumor           1
# Name: count, dtype: int64

# %%
# Prepare features and target variable
X = COAD.drop(['gdc_file_uuid', 'filename', 'age_at_diagnosis', 'aliquot_uuid',
       'case_uuid', 'days_to_death', 'disease_type', 'ethnicity',
       'experimental_strategy', 'gender', 'investigation', 'platform',
       'primary_site', 'race', 'reference_genome', 'sample_type',
       'sample_uuid', 'vital_status', 'tissue_source_site_label',
       'data_submitting_center_label', 'country_of_sample_procurement',
       'histological_diagnosis_label', 'pathologic_t_label',
       'pathologic_n_label', 'pathologic_stage_label', 'icd03_histology_label',
       'icd03_histology_site', 'icd10', 'portion_is_ffpe',
       'new_tumor_event_after_initial_trtmt',
       'primary_therapy_outcome_success_label', 'portion_weight',
       'aliquot_concentration', 'analyte_A260A280Ratio', 'analyte_amount',
       'analyte_type_label', 'radiation_therapy_code_label',
       'radiation_therapy_site_label', 'radiation_therapy_type_label',
       'year_of_diagnosis', 'vital_status_label'], axis=1)
X_scaled = scaler.fit_transform(X)
X_scaled
y = COAD['sample_type']
print("Unique values of y:", np.unique(y))
le = LabelEncoder()
y = le.fit_transform(y)
y
print("Unique values of y:", np.unique(y))
unique_labels, label_counts = np.unique(y, return_counts=True)
min_count = np.min(label_counts)
minority_class_labels = unique_labels[label_counts == min_count]
print("Label of the minority class:", minority_class_labels)
# Out:
# Unique values of y: ['Blood Derived Normal' 'Metastatic' 'Primary Tumor' 'Recurrent Tumor'
#  'Solid Tissue Normal']
# Unique values of y: [0 1 2 3 4]
# Label of the minority class: [1 3]

# %%
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler

oversampler = RandomOverSampler(sampling_strategy='not majority', random_state=42)
X_scaled, y = oversampler.fit_resample(X_scaled,y)
print(X_scaled.shape)
print(y.shape)
# Out:
# (4125, 1273)
# (4125,)

# %%
# Split the resampled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42, stratify=y)

# Define parameters for XGBoost model
params = {
    'learning_rate':[0.01, 0.1],
    'max_depth': [3, 6, 9],
    'eta': [0.01, 0.1],
    #'lambda': [0.1, 1]
    'alpha': [0.01, 0.1],
    'n_estimators': [20, 50, 100]
}

# Initialize XGBoost classifier
xgb_model = xgb.XGBClassifier(objective='multi:softmax', num_class=5, eval_metric='mlogloss', seed=42)

# Perform Grid Search
grid_search = GridSearchCV(estimator=xgb_model, param_grid=params, scoring='accuracy', cv=5)
grid_search.fit(X_train, y_train)

# Get the best parameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)

# Evaluate the model on the test set
test_score = grid_search.best_estimator_.score(X_test, y_test)
print("Test Set Accuracy:", test_score)

# Get the predicted labels
y_pred = grid_search.best_estimator_.predict(X_test)

# Calculate and display confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Blood Derived Normal', 'Metastatic', 'Primary Tumor', 'Recurrent Tumor',
 'Solid Tissue Normal'])
plt.figure(figsize=(8, 6))  # Adjust the figure size if needed
cm_display.plot()  # Plot confusion matrix
plt.xticks(rotation=45, ha='right')  # Rotate x-labels by 45 degrees
plt.show()
# Out:
# Best Parameters: {'alpha': 0.01, 'eta': 0.01, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# Best Score: 0.9927263677415098
# Test Set Accuracy: 0.9919224555735057

# %%
# Train XGBoost model with best parameters
best_xgb_model = xgb.XGBClassifier(objective='multi:softmax', num_class=5, eval_metric='mlogloss', **best_params)
best_xgb_model.fit(X_train, y_train)
# Get feature importances
feature_importances = best_xgb_model.feature_importances_

# Get indices of top 20 features
top_20_indices = feature_importances.argsort()[::-1][:20]

# Get feature names
feature_names = X.columns

# Plot feature importances
plt.figure(figsize=(10, 8))
sns.barplot(x=feature_importances[top_20_indices], y=feature_names[top_20_indices], palette="viridis")
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Top 20 Important Features')
plt.show()

# %%
import shap

# Train XGBoost model with best parameters
best_xgb_model = xgb.XGBClassifier(objective='multi:softmax', num_class=5, eval_metric='mlogloss', **best_params)
best_xgb_model.fit(X_train, y_train)

# Use SHAP to explain the model's predictions
explainer = shap.TreeExplainer(best_xgb_model)
shap_values = explainer.shap_values(X_test)

feature_names = X.columns

# Visualize the SHAP values with feature names
shap.summary_plot(shap_values, X_test, feature_names=feature_names, class_names=['Blood Derived Normal', 'Metastatic', 'Primary Tumor', 'Recurrent Tumor', 'Solid Tissue Normal'])

# %%
data = {}
top_20_feature_names = feature_names[top_20_indices]
#abundance_scaled = np.log2(abundance_df + 10)

# Iterate over the columns of the DataFrame
for column_name in top_20_feature_names:
    data[column_name] = abundance_df[column_name]

plt.figure(figsize=(10, 5))
# Creating a box plot
plt.boxplot(data.values(), widths=0.7, patch_artist=True, 
            boxprops=dict(facecolor='lightblue'), whiskerprops=dict(color='black'))

plt.ylim(-7, 28)
plt.ylabel('Relative Abundance', fontsize=11)

# Adding x-axis tick labels
plt.xticks(range(1, len(data) + 1), data.keys(), rotation=45, ha='right', fontsize=6)  # Adjust fontsize here

# Displaying the plot
plt.tight_layout()  # Adjusts subplot parameters to give specified padding
plt.show()
